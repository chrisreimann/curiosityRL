# %%
import gymnasium as gym
import numpy as np
from EpsilonGreedy import EpsilonGreedy
from gymnasium.envs.registration import register
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.12.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
model = EpsilonGreedy("GridWorld-v0", 25)
model.learn(50000, batchsize=100)

# %%
model.test(1000)
model.learningGraph()
# Out:
# Average return:  0.0

# %%
modelIM = EpsilonGreedy("GridWorld-v0", 25, IM=True)
modelIM.learn(50000, batchsize=100)
# Out:
# c:\Users\c-rei\Documents\Code\curiosityRL\.venv\Lib\site-packages\gymnasium\envs\registration.py:694: UserWarning: WARN: Overriding environment GridWorld-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")

# %%
modelIM.test(1000)
modelIM.learningGraph()
# Out:
# Average return:  1.0

# %%
# See model in action
modelT = modelIM
env = gym.make("GridWorld-v0", render_mode="human", size=modelT.env.size)
observation, info = env.reset()

for _ in range(500):
    action = modelT.predict(observation)
    observation, reward, terminated, truncated, info = env.step(action)

    if terminated or truncated:
        observation, info = env.reset()

env.close()
# Out:
# c:\Users\c-rei\Documents\Code\curiosityRL\.venv\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.size to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.size` for environment variables or `env.get_wrapper_attr('size')` that will search the reminding wrappers.
#   logger.warn(
