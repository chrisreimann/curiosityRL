# %%
import gymnasium as gym
import minigrid
import numpy as np
from EpsilonGreedy import EpsilonGreedy
from simpleTabEnv import GridWorldEnv
from gymnasium.envs.registration import register
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.12.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
model = EpsilonGreedy("GridWorld-v0", 25)
model.learn(50000, batchsize=100)

# %%
modelIM = EpsilonGreedy("GridWorld-v0", 25, IM=True)
modelIM.learn(50000, batchsize=100)

# %%
model.test(1000)
model.learningGraph()
# Out:
# Average return:  0.0

# %%
modelIM.test(1000)
modelIM.learningGraph()
# Out:
# Average return:  1.0

# %%
modelT = model
env = gym.make("GridWorld-v0", render_mode="human", size=modelT.env.size)
observation, info = env.reset()

for _ in range(500):
    action = modelT.predict(observation)
    observation, reward, terminated, truncated, info = env.step(action)

    if terminated or truncated:
        observation, info = env.reset()

env.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 7
#       5 for _ in range(500):
#       6     action = modelT.predict(observation)
# ----> 7     observation, reward, terminated, truncated, info = env.step(action)
#       9     if terminated or truncated:
#      10         observation, info = env.reset()
#
# File c:\Users\c-rei\Documents\Code\curiosityRL\.venv\Lib\site-packages\gymnasium\wrappers\time_limit.py:57, in TimeLimit.step(self, action)
#      46 def step(self, action):
#      47     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#      48
#      49     Args:
#    (...)
#      55
#      56     """
# ---> 57     observation, reward, terminated, truncated, info = self.env.step(action)
#      58     self._elapsed_steps += 1
#      60     if self._elapsed_steps >= self._max_episode_steps:
#
# File c:\Users\c-rei\Documents\Code\curiosityRL\.venv\Lib\site-packages\gymnasium\wrappers\order_enforcing.py:56, in OrderEnforcing.step(self, action)
#      54 if not self._has_reset:
#      55     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 56 return self.env.step(action)
#
# File c:\Users\c-rei\Documents\Code\curiosityRL\.venv\Lib\site-packages\gymnasium\wrappers\env_checker.py:51, in PassiveEnvChecker.step(self, action)
#      49     return env_step_passive_checker(self.env, action)
#      50 else:
# ---> 51     return self.env.step(action)
#
# File c:\Users\c-rei\Documents\Code\curiosityRL\simpleTabEnv.py:97, in GridWorldEnv.step(self, action)
#      94 info = self._get_info()
#      96 if self.render_mode == "human":
# ---> 97     self._render_frame()
#      99 return observation, reward, terminated, False, info
#
# File c:\Users\c-rei\Documents\Code\curiosityRL\simpleTabEnv.py:162, in GridWorldEnv._render_frame(self)
#     158     pygame.display.update()
#     160     # We need to ensure that human-rendering occurs at the predefined framerate.
#     161     # The following line will automatically add a delay to keep the framerate stable.
# --> 162     self.clock.tick(self.metadata["render_fps"])
#     163 else:  # rgb_array
#     164     return np.transpose(
#     165         np.array(pygame.surfarray.pixels3d(canvas)), axes=(1, 0, 2)
#     166     )
#
# KeyboardInterrupt:
